# %%
import random
data=[random.random() for _ in range(10)]
random.seed(0)
print ("before")
print (data)
print (data.sort())
print (data)
len(data)
hasil=15%2
print ( hasil)
# Out:
# before
# [0.8444218515250481, 0.7579544029403025, 0.420571580830845, 0.25891675029296335, 0.5112747213686085, 0.4049341374504143, 0.7837985890347726, 0.30331272607892745, 0.4765969541523558, 0.5833820394550312]
# None
# [0.25891675029296335, 0.30331272607892745, 0.4049341374504143, 0.420571580830845, 0.4765969541523558, 0.5112747213686085, 0.5833820394550312, 0.7579544029403025, 0.7837985890347726, 0.8444218515250481]
# 1
